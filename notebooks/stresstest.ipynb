# %%
"""
Download and stores FRP products
"""

from wekeo.download import get_FRP_products

sday = "2022-07-15"
eday = "2022-07-20"

files = get_FRP_products(
    start_date = sday,
    end_date = eday,
)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 sday = "2022-07-15"
#       8 eday = "2022-07-20"
# ---> 10 files = get_FRP_products(
#      11     start_date = sday,
#      12     end_date = eday,
#      13 )
#
# File ~/projects/wekeo/wekeo/download.py:159, in get_FRP_products(start_date, end_date, area)
#     156 json_query = format_query(start_date, end_date, area)
#     157 query = hda_client.search(json_query)
# --> 159 results = download(query, archive_dir=get_storage_path(), rm_archive=False)
#     160 return results
#
# File ~/projects/wekeo/wekeo/download.py:77, in download(query, archive_dir, extract_dir, rm_archive)
#      75     print(f"Downloading {len(missing)} files...")
#      76     query.results = missing
# ---> 77     query.download(download_dir=archive_dir)
#      78 else:
# ...
